# %% [markdown]
# <a href="https://colab.research.google.com/github/Vedhasree28/Python-/blob/main/Basic_python_programs.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **1. Write a program to read a number from the user and print whether it is even or odd.**

# %%
number = int(input("Enter a number: "))
if number % 2 == 0:
    print("The number is even.")
else:
    print("The number is odd.")
# Out:
# Enter a number: 2
# The number is even.

# %% [markdown]
# **2. Write a program to find the largest of three numbers entered by the user.**

# %%
a=int(input("Enter first number: "))
b=int(input("Enter second number: "))
c=int(input("Enter third number: "))
d=max(a,b,c)
print("The largest number is:", d)
# Out:
# Enter first number: 3
# Enter second number: 4
# Enter third number: 5
# The largest number is: 5

# %%
a=int(input("Enter first number: "))
b=int(input("Enter second number: "))
c=int(input("Enter third number: "))
if a>=b & a>=c:
  print("a is greater")
elif b>=a & b>=c:
  print("b is greater ")
else:
  print("C is greater")
# Out:
# Enter first number: 6
# Enter second number: 6
# Enter third number: 8
# C is greater

# %% [markdown]
# **3. Write a program to check whether a given number is prime.**

# %%
n=int(input("Enter any number:"))
if n>1:
  for i in range(2,n):
    if n%i == 0:
      print("not prime")
      break
  else:
    print("prime")
else:
  print("not prime")
# Out:
# Enter any number:9
# not prime

# %% [markdown]
# **4. Write a program to print the multiplication table of a number entered by the user.**

# %%
n=int(input("enter:"))
for i in range(1,11):
  print(f"{n}*{i}={n*i}")
# Out:
# enter:4
# 4*1=4
# 4*2=8
# 4*3=12
# 4*4=16
# 4*5=20
# 4*6=24
# 4*7=28
# 4*8=32
# 4*9=36
# 4*10=40

# %% [markdown]
# **5. Write a program to calculate the factorial of a given number.**

# %%
n=int(input("enter:"))
fact=1
for i in range(1,n+1):
  fact*=i
print(fact)
# Out:
# enter:5
# 120
