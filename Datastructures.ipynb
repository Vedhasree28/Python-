# %% [markdown]
# <a href="https://colab.research.google.com/github/Vedhasree28/Python-/blob/main/Datastructures.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# sum of elements in lst
nums=[10,12,5,2,20]
count=0
n=0
while n<len(nums):
  count+=nums[n]
  n+=1
print(count)
# Out:
# 49
